# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    cropped = img[y:y+h,x:x+w]
cv2.imshow('Cropped Face',img)

# %%
# %matplotlib inline

import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
img = cv2.imread('43M_SP_O.bmp')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cat=cv2.imshow('Face',img)
cv2.waitKey()
# Out:
# -1

# %%
img = cv2.imread('43M_SP_O.bmp')

# %%
img = mpimg.imread('43M_SP_O.bmp')
imgplot = plt.imshow(img)

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    cropped = img[y:y+h,x:x+w]
cv2.imshow('Cropped Face',img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-27-ba43197493b8> in <module>()
# ----> 1 faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       2 for (x,y,w,h) in faces:
#       3     cropped = img[y:y+h,x:x+w]
#       4 cv2.imshow('Cropped Face',img)
#
# error: C:\projects\opencv-python\opencv\modules\objdetect\src\cascadedetect.cpp:1698: error: (-215) !empty() in function cv::CascadeClassifier::detectMultiScale
